# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
directory_path = "/content/drive/MyDrive/Data Science Capstone Project/Data/"

csv_dict = {}

for file_name in os.listdir(directory_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(directory_path, file_name)
        df = pd.read_csv(file_path, index_col="Time")
        key = os.path.splitext(file_name)[0]
        csv_dict[key] = df

print(f"Loaded {len(csv_dict)} CSV files:")
print(csv_dict.keys())
# Out:
# Loaded 441 CSV files:
# ...

# %%
for k, v in csv_dict.items():
  if v.shape[1] != 2:
    print(k)
    display(v.head())
# csv_dict['MATLAB 2-14 PM Tue, Oct 22, 2024 Run5 ']
# Out:
# MATLAB 2-50 PM Tue, Mar 19, 2024 Run0
#                0         1         2         3
# Time
# 0.0000  0.000234 -0.000131  0.000206  0.000526
# 0.0001  0.000401 -0.000073  0.000215  0.000535
# 0.0002  0.000315 -0.000125  0.000212  0.000529
# 0.0003  0.000292 -0.000243  0.000228  0.000540
# 0.0004  0.000256  0.000039  0.000250  0.000560

# %% [markdown]
# ### Cleaning

# %%
# def clean_inplace(df):
#     columns_to_drop = [col for col in df.columns if col.endswith('_Time') and col != 'UntitledPXI1Slot2_ai0_Time']
#     df.drop(columns=columns_to_drop, inplace=True)
#     df.rename(columns=lambda col: col.split('_')[-1], inplace=True)
#     df.set_index('Time', inplace=True)
#     df.rename(columns=lambda col: col.replace('ai', ''), inplace=True)


# for df in csv_dict.values():
#     clean_inplace(df)
#     df.index = df.index.round(4)


# def save_dataframes_to_directory(csv_dict, directory_path):
#     # Ensure the directory exists
#     os.makedirs(directory_path, exist_ok=True)

#     # Loop through the dictionary and save each DataFrame as a CSV file
#     for filename, dataframe in csv_dict.items():
#         # Construct the full file path
#         file_path = os.path.join(directory_path, f"{filename}.csv")
#         # Save the DataFrame to the file
#         dataframe.to_csv(file_path, index=True)
#         print(f"Saved: {file_path}")

# # Specify the target directory
# target_directory = "/content/drive/MyDrive/Data Science Capstone Project/Cleaned_Data"

# # Call the function
# save_dataframes_to_directory(csv_dict, target_directory)
